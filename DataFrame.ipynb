# %%
import pandas as pd

# %%
xyz_web = {'day':[1,2,3,4,5,6], "visitors":[1000,700,6000,1000,400,350],"Bunce_rate":[20,20,23,15,10,34]}

# %%
df=pd.DataFrame(xyz_web)

# %%
df.head(2)
# Out:
#    day  visitors  Bunce_rate
# 0    1      1000          20
# 1    2       700          20

# %%
df1 = pd.DataFrame({"HPI":[80,90,70,60],"Int_Rate":[2,1,2,3],"Ind_GDP":[50,45,45,67]},
                  index = [2001,2002,2003,2004])

# %%
df2 = pd.DataFrame({"HPI":[80,90,70,60],"Int_Rate":[2,1,2,3],"Ind_GDP":[50,45,45,67]},
                   index = [2005,2006,2007,2008])

# %%
df1
# Out:
#       HPI  Int_Rate  Ind_GDP
# 2001   80         2       50
# 2002   90         1       45
# 2003   70         2       45
# 2004   60         3       67

# %%
df2
# Out:
#       HPI  Int_Rate  Ind_GDP
# 2005   80         2       50
# 2006   90         1       45
# 2007   70         2       45
# 2008   60         3       67

# %%
merge = pd.merge(df1,df2, on="HPI")

# %%
print(merge)
# Out:
#    HPI  Int_Rate_x  Ind_GDP_x  Int_Rate_y  Ind_GDP_y
# 0   80           2         50           2         50
# 1   90           1         45           1         45
# 2   70           2         45           2         45
# 3   60           3         67           3         67

# %%
df3 = pd.DataFrame({"HPI":[1,2,3,4],"Int_Rate":[5,6,8,9]},
                  index = [2001,2002,2003,2004])
df4 = pd.DataFrame({"low_tier_HPI":[80,90,70,60],"unemployment":[2,1,2,3]},
                   index = [2001,2003,2004,2004])

# %%
joined = df3.join(df4)

# %%
joined
# Out:
#       HPI  Int_Rate  low_tier_HPI  unemployment
# 2001    1         5          80.0           2.0
# 2002    2         6           NaN           NaN
# 2003    3         8          90.0           1.0
# 2004    4         9          70.0           2.0
# 2004    4         9          60.0           3.0

# %%
d = pd.DataFrame({"day":[1,2,3,4], "visitors":[200,100,230,300],"bousce_rate":[20,25,60,10]})

# %%
d.set_index("day", inplace=True)

# %%
d
# Out:
#      visitors  bousce_rate
# day
# 1         200           20
# 2         100           25
# 3         230           60
# 4         300           10

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import style

# %%
style.use("fivethirtyeight")

# %%
d.plot()

# %%
d= d.rename(columns={"visitors":"users"})

# %%
d
# Out:
#      users  bousce_rate
# day
# 1      200           20
# 2      100           25
# 3      230           60
# 4      300           10

# %%
concat=pd.concat([df1,df2])

# %%
concat
# Out:
#       HPI  Int_Rate  Ind_GDP
# 2001   80         2       50
# 2002   90         1       45
# 2003   70         2       45
# 2004   60         3       67
# 2005   80         2       50
# 2006   90         1       45
# 2007   70         2       45
# 2008   60         3       67

# %%
bank = pd.read_csv("C:\\Users\\hp\\Desktop\\Data\\bank.csv",index_col=0)

# %%
bank
# Out:
#            CustomerId         Surname  CreditScore Geography  Gender  Age  \
# RowNumber
# 1            15634602        Hargrave          619    France  Female   42
# 2            15647311            Hill          608     Spain  Female   41
# 3            15619304            Onio          502    France  Female   42
# 4            15701354            Boni          699    France  Female   39
# 5            15737888        Mitchell          850     Spain  Female   43
# 6            15574012             Chu          645     Spain    Male   44
# 7            15592531        Bartlett          822    France    Male   50
# 8            15656148          Obinna          376   Germany  Female   29
# 9            15792365              He          501    France    Male   44
# 10           15592389              H?          684    France    Male   27
# 11           15767821          Bearce          528    France    Male   31
# ...

# %%
bank.to_html("bank.html")
